# %%
pip install Tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula as tb

# %%
import pandas as pd

# %%
df=tb.convert_into('E:/Companies Assignment.pdf','company.csv',pages='all')

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\Python'

# %%
df1=pd.read_csv('C:/Users/Admin/Desktop/Python/company.csv')

# %% [markdown]
# df1.head()

# %%
df1.shape
# Out:
# (1024, 5)

# %%
df=df1.drop(0,axis=0)

# %%
df.head()
# Out:
#   Unnamed: 0  Administration  Marketing Spend       State     Profit
# 1   165349.2       136897.80        471784.10    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99
# 5  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.rename(columns={'Unnamed: 0':'R&D'},inplace=True)
df.head()
# Out:
#          R&D  Administration  Marketing Spend       State     Profit
# 1   165349.2       136897.80        471784.10    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99
# 5  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.isnull().sum()
# Out:
# R&D                25
# Administration     28
# Marketing Spend    29
# State              23
# Profit             23
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
x=df[['R&D','Marketing Spend','Administration']]
y=df['Profit']

# %%
model= LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([200413.17807185, 212535.19254472, 149248.88763639, 161608.61022018,
#        128900.92050003, 132419.77557482, 166220.86238597, 178644.97032217,
#        175894.96988248, 132718.21456838, 116943.33165837,  97301.57178859,
#        132805.54535921, 141047.83678295, 179542.5578194 , 139701.63980312,
#        119233.80098927, 155560.20438172, 121000.30255544, 136563.27978545,
#        112674.63050034, 157874.77452198, 121679.75353932,  99575.80488447,
#         83669.53725316, 121184.20894275, 131616.32964238, 130481.08168184,
#        167728.51014815, 133933.49134175,  89452.07207176, 129576.47765608,
#        101362.89157977,  82541.64015674,  93464.58500283,  20281.27531743,
#         48001.09869461,  81743.29491527,  43301.39449542,  52277.95389407,
#         72781.00920632, 105960.75128618,  58609.53786471,  74539.4208482 ,
#         70333.35837887, -21572.01578238,  53831.46967902, 123720.11747775,
# ...

# %%
model.coef_
# Out:
# array([0.53579177, 0.08450176, 1.10171662])

# %%
model.intercept_
# Out:
# -78868.72994473674

# %%
r2_score(y,model.predict(x))
# Out:
# 0.9536852791410393

# %% [markdown]
# # Train Test Split

# %%
df1.head()
# Out:
#   Unnamed: 0  Administration  Marketing Spend       State     Profit
# 0      Spend             NaN              NaN         NaN        NaN
# 1   165349.2       136897.80        471784.10    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=1)

# %%
model= LinearRegression()

# %% [markdown]
# # Train Accuracy

# %%
model= model.fit(x_train,y_train)

# %%
model.coef_
# Out:
# array([0.64705731, 0.02268115, 1.16642956])

# %%
model.intercept_
# Out:
# -81919.59456589851

# %%
model.predict(x_train)
# Out:
# array([143757.55112923,  79812.5000996 , 159809.1925735 , 123906.61282613,
#         64561.80090465,  55288.82349658,  78442.78533912,  84625.05805437,
#         87499.99172084, 183464.60646772, 159247.32464464,  62901.22673511,
#        154580.62794552, 140984.46131887, 149452.18120019, 161535.36111741,
#         55558.34488499,  98082.26812884, 186355.07562442,  83356.32416215,
#        155967.60440295, 115885.97060301, 105020.60259164, 195453.05998943,
#        161725.23965596,  82276.60570624,  81363.4626096 ,  79573.4257814 ,
#        131355.03012918, 174741.41367348, 182876.84605288,  72850.86234314,
#        132380.37418979, 157099.97104969, 165011.0014989 , 117439.52230306,
#        156062.54367222, 132778.25606608, 127501.35875841, 129920.58397992,
#        163055.25252805, 174260.67572813, 138080.18275749, 109735.63197044,
#         77101.55236905, 118495.93746303,  85657.30681845, 159973.17850943,
# ...

# %%
r2_score(y_train,model.predict(x_train))
# Out:
# 0.9455824957579994

# %% [markdown]
# # test Accuracy

# %%
model=model.fit(x_test,y_test)

# %%
model.coef_
# Out:
# array([ 0.80527242,  0.03186368, -0.08388051])

# %%
model.intercept_
# Out:
# 56362.40194800737

# %%
model.predict(x_test)
# Out:
# array([ 55247.95756336,  64929.62884909, 109539.47566304,  90571.70438834,
#         98657.42068084, 118104.49106233, 154294.56463768,  74683.0668361 ,
#         71633.83591886, 100167.08474262,  90946.77090002, 156486.93078354,
#        140179.5901215 , 156605.62365093, 145084.50318596,  81063.46933069,
#         91068.09081993, 180901.21896973,  90972.40186407, 139394.42811062,
#        101252.98345215, 184937.24219205, 156056.26655436,  77887.7922997 ,
#        103431.61579875, 162745.09504258, 104983.99813781,  79771.66850892,
#        140515.35581605, 152440.59122212, 139136.40968925,  87976.14161702,
#        155166.8719368 , 138342.70402437,  83615.45946367,  88969.76883606,
#        172046.57362373, 154834.52370761,  78567.0129754 ,  86572.41889041,
#         91900.24293769, 154455.18537471,  62139.15424547, 161895.85561478,
#        174688.27213451, 169939.70798585,  75195.637996  ,  60500.59743826,
# ...

# %%
r2_score(y_test,model.predict(x_test))
# Out:
# 0.9981616155022264

# %% [markdown]
# # train accuracy is 0.9455824957579994 and test accuracy is 0.9981616155022264 both are nearly same so this is overfit.

# %%
import seaborn as sns

# %%
sns.relplot(data=df,x='Marketing Spend',y='Administration')
sns.set_style('dark')

# %%
sns.barplot(data=df,x='State',y='Profit',ci=None)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.countplot(df['State'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
df.corr()
# Out:
#                  Administration  Marketing Spend    Profit
# Administration         1.000000         0.529498  0.747417
# Marketing Spend        0.529498         1.000000  0.916999
# Profit                 0.747417         0.916999  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df.Profit)
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.boxplot(data=df,x='State',y='Profit')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.relplot(data=df,x='R&D',y='Administration')

# %%
df.head()
# Out:
#          R&D  Administration  Marketing Spend       State     Profit
# 1   165349.2       136897.80        471784.10    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99
# 5  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.pairplot(df,vars=['R&D','Administration','Marketing Spend','State','Profit'])

# %%
sns.histplot(df.Profit)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Count'>

# %%
sns.distplot(df.Profit)
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
df

# %%
sns.barplot(data=df,x='Marketing Spend',y='Administration',hue='State',ci=0)
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Administration'>

# %%
df.head()
# Out:
#          R&D  Administration  Marketing Spend       State     Profit
# 1   165349.2       136897.80        471784.10    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99
# 5  142107.34        91391.77        366168.42     Florida  166187.94
